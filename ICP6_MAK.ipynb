# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import EarlyStopping

# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Define EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=5,  # Number of epochs with no improvement after which training will be stopped
                               restore_best_weights=True)  # Restores model to best weights with the lowest validation loss

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
autoencoder.fit(x_train, x_train,  # For autoencoders, input and output are the same
                epochs=100,  # Set a high number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[early_stopping])  # Add the early stopping callback
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.4336 - val_loss: 0.2378
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2255 - val_loss: 0.1927
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1902 - val_loss: 0.1789
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1758 - val_loss: 0.1657
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1651 - val_loss: 0.1598
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1606 - val_loss: 0.1579
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1591 - val_loss: 0.1568
# Epoch 8/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1579 - val_loss: 0.1560
# Epoch 9/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1575 - val_loss: 0.1553
# Epoch 10/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1564 - val_loss: 0.1539
# Epoch 11/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1549 - val_loss: 0.1515
# Epoch 12/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1526 - val_loss: 0.1497
# Epoch 13/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1506 - val_loss: 0.1479
# Epoch 14/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1488 - val_loss: 0.1460
# Epoch 15/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1475 - val_loss: 0.1441
# Epoch 16/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1448 - val_loss: 0.1425
# Epoch 17/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1432 - val_loss: 0.1418
# Epoch 18/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1433 - val_loss: 0.1412
# Epoch 19/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1428 - val_loss: 0.1407
# Epoch 20/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1421 - val_loss: 0.1404
# Epoch 21/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1418 - val_loss: 0.1401
# Epoch 22/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1415 - val_loss: 0.1399
# Epoch 23/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1412 - val_loss: 0.1396
# Epoch 24/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1410 - val_loss: 0.1393
# Epoch 25/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1407 - val_loss: 0.1391
# Epoch 26/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1406 - val_loss: 0.1387
# Epoch 27/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1402 - val_loss: 0.1386
# Epoch 28/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1402 - val_loss: 0.1385
# Epoch 29/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1399 - val_loss: 0.1383
# Epoch 30/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1398 - val_loss: 0.1381
# Epoch 31/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1397 - val_loss: 0.1378
# Epoch 32/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1398 - val_loss: 0.1377
# Epoch 33/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1394 - val_loss: 0.1376
# Epoch 34/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1393 - val_loss: 0.1376
# Epoch 35/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1392 - val_loss: 0.1374
# Epoch 36/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1388 - val_loss: 0.1373
# Epoch 37/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1389 - val_loss: 0.1372
# Epoch 38/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1387 - val_loss: 0.1371
# Epoch 39/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1390 - val_loss: 0.1369
# Epoch 40/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1387 - val_loss: 0.1369
# Epoch 41/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1383 - val_loss: 0.1368
# Epoch 42/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1384 - val_loss: 0.1367
# Epoch 43/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1386 - val_loss: 0.1367
# Epoch 44/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1384 - val_loss: 0.1367
# Epoch 45/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1383 - val_loss: 0.1366
# Epoch 46/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1381 - val_loss: 0.1364
# Epoch 47/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1382 - val_loss: 0.1364
# Epoch 48/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1379 - val_loss: 0.1364
# Epoch 49/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1379 - val_loss: 0.1363
# Epoch 50/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1380 - val_loss: 0.1363
# Epoch 51/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1380 - val_loss: 0.1363
# Epoch 52/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1380 - val_loss: 0.1363
# Epoch 53/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1377 - val_loss: 0.1361
# Epoch 54/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1376 - val_loss: 0.1361
# Epoch 55/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1375 - val_loss: 0.1360
# Epoch 56/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1376 - val_loss: 0.1361
# Epoch 57/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1378 - val_loss: 0.1360
# Epoch 58/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1379 - val_loss: 0.1361
# Epoch 59/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1377 - val_loss: 0.1360
# Epoch 60/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1380 - val_loss: 0.1359
# Epoch 61/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1378 - val_loss: 0.1359
# Epoch 62/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1373 - val_loss: 0.1358
# Epoch 63/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1376 - val_loss: 0.1358
# Epoch 64/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1375 - val_loss: 0.1358
# Epoch 65/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1376 - val_loss: 0.1358
# Epoch 66/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1375 - val_loss: 0.1357
# Epoch 67/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1375 - val_loss: 0.1357
# Epoch 68/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1375 - val_loss: 0.1357
# Epoch 69/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1375 - val_loss: 0.1357
# Epoch 70/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1372 - val_loss: 0.1356
# Epoch 71/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1371 - val_loss: 0.1356
# Epoch 72/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1373 - val_loss: 0.1354
# Epoch 73/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1368 - val_loss: 0.1355
# Epoch 74/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1372 - val_loss: 0.1354
# Epoch 75/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1373 - val_loss: 0.1355
# Epoch 76/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1367 - val_loss: 0.1355
# Epoch 77/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1371 - val_loss: 0.1353
# Epoch 78/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1369 - val_loss: 0.1353
# Epoch 79/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1369 - val_loss: 0.1353
# Epoch 80/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - val_loss: 0.1354
# Epoch 81/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1368 - val_loss: 0.1353
# Epoch 82/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1369 - val_loss: 0.1352
# Epoch 83/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1367 - val_loss: 0.1351
# Epoch 84/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1370 - val_loss: 0.1350
# Epoch 85/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1369 - val_loss: 0.1351
# Epoch 86/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - val_loss: 0.1350
# Epoch 87/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1363 - val_loss: 0.1351
# Epoch 88/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - val_loss: 0.1349
# Epoch 89/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1362 - val_loss: 0.1348
# Epoch 90/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1365 - val_loss: 0.1348
# Epoch 91/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1362 - val_loss: 0.1349
# Epoch 92/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1362 - val_loss: 0.1347
# Epoch 93/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1364 - val_loss: 0.1347
# Epoch 94/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1363 - val_loss: 0.1347
# Epoch 95/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1367 - val_loss: 0.1346
# Epoch 96/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1364 - val_loss: 0.1347
# Epoch 97/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1362 - val_loss: 0.1346
# Epoch 98/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1364 - val_loss: 0.1346
# Epoch 99/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1360 - val_loss: 0.1347
# Epoch 100/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1361 - val_loss: 0.1344

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import TerminateOnNaN

# Define the TerminateOnNaN callback
terminate_on_nan = TerminateOnNaN()

# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
# Assuming x_train and x_test are your training and validation datasets
autoencoder.fit(x_train, x_train,  # For autoencoders, input and output are the same
                epochs=30,  # Set the number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[terminate_on_nan])  # Add the TerminateOnNaN callback
# Out:
# Epoch 1/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.4497 - val_loss: 0.2520
# Epoch 2/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2436 - val_loss: 0.2096
# Epoch 3/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2047 - val_loss: 0.1898
# Epoch 4/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1889 - val_loss: 0.1812
# Epoch 5/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1810 - val_loss: 0.1756
# Epoch 6/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1754 - val_loss: 0.1696
# Epoch 7/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1699 - val_loss: 0.1660
# Epoch 8/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1669 - val_loss: 0.1635
# Epoch 9/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1646 - val_loss: 0.1617
# Epoch 10/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1626 - val_loss: 0.1598
# Epoch 11/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1610 - val_loss: 0.1578
# Epoch 12/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1588 - val_loss: 0.1562
# Epoch 13/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1574 - val_loss: 0.1548
# Epoch 14/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1559 - val_loss: 0.1531
# Epoch 15/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1539 - val_loss: 0.1511
# Epoch 16/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1521 - val_loss: 0.1501
# Epoch 17/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1514 - val_loss: 0.1496
# Epoch 18/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1506 - val_loss: 0.1492
# Epoch 19/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1503 - val_loss: 0.1486
# Epoch 20/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1499 - val_loss: 0.1482
# Epoch 21/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1497 - val_loss: 0.1481
# Epoch 22/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1491 - val_loss: 0.1477
# Epoch 23/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1491 - val_loss: 0.1474
# Epoch 24/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1486 - val_loss: 0.1472
# Epoch 25/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1484 - val_loss: 0.1470
# Epoch 26/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1482 - val_loss: 0.1468
# Epoch 27/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1481 - val_loss: 0.1466
# Epoch 28/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1478 - val_loss: 0.1464
# Epoch 29/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1476 - val_loss: 0.1463
# Epoch 30/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1475 - val_loss: 0.1462

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the ModelCheckpoint callback
checkpoint = ModelCheckpoint(filepath='autoencoder_best.keras',  # File path to save the model
                             monitor='val_loss',  # Metric to monitor
                             save_best_only=True,  # Save only the best model (based on the monitored metric)
                             mode='min',  # Minimize the monitored metric (e.g., validation loss)
                             save_weights_only=False,  # Save the entire model (set to True to save only weights)
                             verbose=1)  # Print a message when saving the model


# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
# Assuming x_train and x_test are your training and validation datasets
autoencoder.fit(x_train, x_train,  # For autoencoders, input and output are the same
                epochs=30,  # Number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),  # Validation data
                callbacks=[checkpoint])  # Add the ModelCheckpoint callback
# Out:
# Epoch 1/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4131
# Epoch 1: val_loss improved from inf to 0.25051, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.4127 - val_loss: 0.2505
# Epoch 2/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2392
# Epoch 2: val_loss improved from 0.25051 to 0.21085, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2389 - val_loss: 0.2109
# Epoch 3/30
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2074
# Epoch 3: val_loss improved from 0.21085 to 0.19280, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2072 - val_loss: 0.1928
# Epoch 4/30
# 218/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1903
# Epoch 4: val_loss improved from 0.19280 to 0.17790, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1900 - val_loss: 0.1779
# Epoch 5/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1773
# Epoch 5: val_loss improved from 0.17790 to 0.16959, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1773 - val_loss: 0.1696
# Epoch 6/30
# 218/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1698
# Epoch 6: val_loss improved from 0.16959 to 0.16485, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1697 - val_loss: 0.1648
# Epoch 7/30
# 222/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1654
# Epoch 7: val_loss improved from 0.16485 to 0.16218, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1654 - val_loss: 0.1622
# Epoch 8/30
# 224/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1629
# Epoch 8: val_loss improved from 0.16218 to 0.15958, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1629 - val_loss: 0.1596
# Epoch 9/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1604
# Epoch 9: val_loss improved from 0.15958 to 0.15769, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1604 - val_loss: 0.1577
# Epoch 10/30
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1590
# Epoch 10: val_loss improved from 0.15769 to 0.15663, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1590 - val_loss: 0.1566
# Epoch 11/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1577
# Epoch 11: val_loss improved from 0.15663 to 0.15604, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1577 - val_loss: 0.1560
# Epoch 12/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1570
# Epoch 12: val_loss improved from 0.15604 to 0.15541, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1570 - val_loss: 0.1554
# Epoch 13/30
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1567
# Epoch 13: val_loss improved from 0.15541 to 0.15484, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1567 - val_loss: 0.1548
# Epoch 14/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1558
# Epoch 14: val_loss improved from 0.15484 to 0.15408, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1558 - val_loss: 0.1541
# Epoch 15/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1552
# Epoch 15: val_loss improved from 0.15408 to 0.15333, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1552 - val_loss: 0.1533
# Epoch 16/30
# 221/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1548
# Epoch 16: val_loss improved from 0.15333 to 0.15263, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1548 - val_loss: 0.1526
# Epoch 17/30
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1536
# Epoch 17: val_loss improved from 0.15263 to 0.15198, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1536 - val_loss: 0.1520
# Epoch 18/30
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1529
# Epoch 18: val_loss improved from 0.15198 to 0.15112, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1529 - val_loss: 0.1511
# Epoch 19/30
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1525
# Epoch 19: val_loss improved from 0.15112 to 0.15043, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1525 - val_loss: 0.1504
# Epoch 20/30
# 220/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1516
# Epoch 20: val_loss improved from 0.15043 to 0.14965, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1515 - val_loss: 0.1496
# Epoch 21/30
# 209/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1508
# Epoch 21: val_loss improved from 0.14965 to 0.14899, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1508 - val_loss: 0.1490
# Epoch 22/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1503
# Epoch 22: val_loss improved from 0.14899 to 0.14834, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1503 - val_loss: 0.1483
# Epoch 23/30
# 225/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1501
# Epoch 23: val_loss improved from 0.14834 to 0.14791, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1501 - val_loss: 0.1479
# Epoch 24/30
# 226/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1495
# Epoch 24: val_loss improved from 0.14791 to 0.14743, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1495 - val_loss: 0.1474
# Epoch 25/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1490
# Epoch 25: val_loss improved from 0.14743 to 0.14696, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1490 - val_loss: 0.1470
# Epoch 26/30
# 225/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1485
# Epoch 26: val_loss improved from 0.14696 to 0.14650, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1485 - val_loss: 0.1465
# Epoch 27/30
# 220/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1481
# Epoch 27: val_loss improved from 0.14650 to 0.14605, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1481 - val_loss: 0.1460
# Epoch 28/30
# 224/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1474
# Epoch 28: val_loss improved from 0.14605 to 0.14552, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1474 - val_loss: 0.1455
# Epoch 29/30
# 224/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1470
# Epoch 29: val_loss improved from 0.14552 to 0.14507, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1470 - val_loss: 0.1451
# Epoch 30/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1465
# Epoch 30: val_loss improved from 0.14507 to 0.14465, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1465 - val_loss: 0.1447

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss',  # Metric to monitor
                              factor=0.5,  # Factor by which the learning rate will be reduced (new_lr = lr * factor)
                              patience=3,  # Number of epochs with no improvement after which learning rate will be reduced
                              min_lr=1e-6,  # Lower bound for the learning rate
                              verbose=1)  # Print message when the learning rate is reduced


# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
# Assuming x_train and x_test are your training and validation datasets
autoencoder.fit(x_train, x_train,  # For autoencoders, input and output are the same
                epochs=30,  # Number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),  # Validation data
                callbacks=[reduce_lr])  # Add the ReduceLROnPlateau callback
# Out:
# Epoch 1/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.4248 - val_loss: 0.2601 - learning_rate: 0.0010
# Epoch 2/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2482 - val_loss: 0.2237 - learning_rate: 0.0010
# Epoch 3/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2182 - val_loss: 0.1938 - learning_rate: 0.0010
# Epoch 4/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1903 - val_loss: 0.1766 - learning_rate: 0.0010
# Epoch 5/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1761 - val_loss: 0.1688 - learning_rate: 0.0010
# Epoch 6/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1682 - val_loss: 0.1622 - learning_rate: 0.0010
# Epoch 7/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1622 - val_loss: 0.1576 - learning_rate: 0.0010
# Epoch 8/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1582 - val_loss: 0.1552 - learning_rate: 0.0010
# Epoch 9/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1563 - val_loss: 0.1540 - learning_rate: 0.0010
# Epoch 10/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1551 - val_loss: 0.1531 - learning_rate: 0.0010
# Epoch 11/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1544 - val_loss: 0.1519 - learning_rate: 0.0010
# Epoch 12/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1530 - val_loss: 0.1507 - learning_rate: 0.0010
# Epoch 13/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1514 - val_loss: 0.1494 - learning_rate: 0.0010
# Epoch 14/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1507 - val_loss: 0.1485 - learning_rate: 0.0010
# Epoch 15/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1494 - val_loss: 0.1475 - learning_rate: 0.0010
# Epoch 16/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1485 - val_loss: 0.1465 - learning_rate: 0.0010
# Epoch 17/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1474 - val_loss: 0.1455 - learning_rate: 0.0010
# Epoch 18/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1464 - val_loss: 0.1444 - learning_rate: 0.0010
# Epoch 19/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1455 - val_loss: 0.1432 - learning_rate: 0.0010
# Epoch 20/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1443 - val_loss: 0.1419 - learning_rate: 0.0010
# Epoch 21/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1431 - val_loss: 0.1411 - learning_rate: 0.0010
# Epoch 22/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1422 - val_loss: 0.1404 - learning_rate: 0.0010
# Epoch 23/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1419 - val_loss: 0.1400 - learning_rate: 0.0010
# Epoch 24/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1412 - val_loss: 0.1396 - learning_rate: 0.0010
# Epoch 25/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1408 - val_loss: 0.1394 - learning_rate: 0.0010
# Epoch 26/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1406 - val_loss: 0.1388 - learning_rate: 0.0010
# Epoch 27/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1401 - val_loss: 0.1386 - learning_rate: 0.0010
# Epoch 28/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1400 - val_loss: 0.1382 - learning_rate: 0.0010
# Epoch 29/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1394 - val_loss: 0.1379 - learning_rate: 0.0010
# Epoch 30/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1394 - val_loss: 0.1375 - learning_rate: 0.0010

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TerminateOnNaN, ReduceLROnPlateau

# EarlyStopping callback to stop training if validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# ModelCheckpoint callback to save the best model based on validation loss
checkpoint = ModelCheckpoint(filepath='autoencoder_best.keras', monitor='val_loss', save_best_only=True, verbose=1)

# TerminateOnNaN callback to stop training if the loss becomes NaN
terminate_on_nan = TerminateOnNaN()

# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5,   patience=3, min_lr=1e-6, verbose=1)

# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Training with multiple callbacks
autoencoder.fit(x_train, x_train,
                epochs=30,  # You can set a high number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[reduce_lr, early_stopping, checkpoint, terminate_on_nan])  # Using multiple callbacks
# Out:
# Epoch 1/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4386
# Epoch 1: val_loss improved from inf to 0.24692, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.4382 - val_loss: 0.2469 - learning_rate: 0.0010
# Epoch 2/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2307
# Epoch 2: val_loss improved from 0.24692 to 0.19920, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2306 - val_loss: 0.1992 - learning_rate: 0.0010
# Epoch 3/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1979
# Epoch 3: val_loss improved from 0.19920 to 0.18606, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1978 - val_loss: 0.1861 - learning_rate: 0.0010
# Epoch 4/30
# 218/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1848
# Epoch 4: val_loss improved from 0.18606 to 0.17644, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1846 - val_loss: 0.1764 - learning_rate: 0.0010
# Epoch 5/30
# 224/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1768
# Epoch 5: val_loss improved from 0.17644 to 0.17118, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1768 - val_loss: 0.1712 - learning_rate: 0.0010
# Epoch 6/30
# 222/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1716
# Epoch 6: val_loss improved from 0.17118 to 0.16753, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1716 - val_loss: 0.1675 - learning_rate: 0.0010
# Epoch 7/30
# 224/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1687
# Epoch 7: val_loss improved from 0.16753 to 0.16502, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1686 - val_loss: 0.1650 - learning_rate: 0.0010
# Epoch 8/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1660
# Epoch 8: val_loss improved from 0.16502 to 0.16283, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1660 - val_loss: 0.1628 - learning_rate: 0.0010
# Epoch 9/30
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1640
# Epoch 9: val_loss improved from 0.16283 to 0.16038, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1639 - val_loss: 0.1604 - learning_rate: 0.0010
# Epoch 10/30
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1615
# Epoch 10: val_loss improved from 0.16038 to 0.15847, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1615 - val_loss: 0.1585 - learning_rate: 0.0010
# Epoch 11/30
# 210/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1599
# Epoch 11: val_loss improved from 0.15847 to 0.15711, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1598 - val_loss: 0.1571 - learning_rate: 0.0010
# Epoch 12/30
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1582
# Epoch 12: val_loss improved from 0.15711 to 0.15618, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1582 - val_loss: 0.1562 - learning_rate: 0.0010
# Epoch 13/30
# 221/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1576
# Epoch 13: val_loss improved from 0.15618 to 0.15539, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1576 - val_loss: 0.1554 - learning_rate: 0.0010
# Epoch 14/30
# 225/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1572
# Epoch 14: val_loss improved from 0.15539 to 0.15493, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1571 - val_loss: 0.1549 - learning_rate: 0.0010
# Epoch 15/30
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1560
# Epoch 15: val_loss improved from 0.15493 to 0.15454, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1560 - val_loss: 0.1545 - learning_rate: 0.0010
# Epoch 16/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1558
# Epoch 16: val_loss improved from 0.15454 to 0.15394, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1558 - val_loss: 0.1539 - learning_rate: 0.0010
# Epoch 17/30
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1551
# Epoch 17: val_loss improved from 0.15394 to 0.15378, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1551 - val_loss: 0.1538 - learning_rate: 0.0010
# Epoch 18/30
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1549
# Epoch 18: val_loss improved from 0.15378 to 0.15319, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1549 - val_loss: 0.1532 - learning_rate: 0.0010
# Epoch 19/30
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1546
# Epoch 19: val_loss improved from 0.15319 to 0.15294, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1545 - val_loss: 0.1529 - learning_rate: 0.0010
# Epoch 20/30
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1546
# Epoch 20: val_loss improved from 0.15294 to 0.15264, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1546 - val_loss: 0.1526 - learning_rate: 0.0010
# Epoch 21/30
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1539
# Epoch 21: val_loss improved from 0.15264 to 0.15220, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1539 - val_loss: 0.1522 - learning_rate: 0.0010
# Epoch 22/30
# 220/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1537
# Epoch 22: val_loss improved from 0.15220 to 0.15194, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1537 - val_loss: 0.1519 - learning_rate: 0.0010
# Epoch 23/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1535
# Epoch 23: val_loss improved from 0.15194 to 0.15169, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1535 - val_loss: 0.1517 - learning_rate: 0.0010
# Epoch 24/30
# 225/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1530
# Epoch 24: val_loss improved from 0.15169 to 0.15113, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1530 - val_loss: 0.1511 - learning_rate: 0.0010
# Epoch 25/30
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1524
# Epoch 25: val_loss improved from 0.15113 to 0.15077, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1524 - val_loss: 0.1508 - learning_rate: 0.0010
# Epoch 26/30
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1512
# Epoch 26: val_loss improved from 0.15077 to 0.14976, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1512 - val_loss: 0.1498 - learning_rate: 0.0010
# Epoch 27/30
# 211/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1507
# Epoch 27: val_loss improved from 0.14976 to 0.14880, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1507 - val_loss: 0.1488 - learning_rate: 0.0010
# Epoch 28/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1501
# Epoch 28: val_loss improved from 0.14880 to 0.14808, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1501 - val_loss: 0.1481 - learning_rate: 0.0010
# Epoch 29/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1495
# Epoch 29: val_loss improved from 0.14808 to 0.14748, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1495 - val_loss: 0.1475 - learning_rate: 0.0010
# Epoch 30/30
# 225/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1489
# Epoch 30: val_loss improved from 0.14748 to 0.14719, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1489 - val_loss: 0.1472 - learning_rate: 0.0010

# %%
from tensorflow.keras.models import load_model

# Load the entire model
best_autoencoder = load_model('autoencoder_best.keras')

# Let's look at the encoded representations
encoded_data = best_autoencoder.predict(x_test)
print(encoded_data)
print(encoded_data.shape)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# [[2.0163922e-10 2.3680084e-11 1.8523325e-11 ... 3.0008762e-10
#   1.0986750e-11 7.8811038e-12]
#  [2.4881977e-14 4.5391537e-16 8.5657681e-15 ... 1.8063024e-15
#   1.9584410e-13 4.0643737e-15]
#  [1.3492281e-10 8.9158497e-10 8.2469781e-10 ... 4.5694579e-10
#   5.5068056e-10 3.1767151e-11]
#  ...
#  [5.5762673e-18 2.6038686e-20 3.9066058e-19 ... 6.3080664e-19
#   3.6704483e-19 1.7425277e-21]
#  [3.4576025e-12 2.2963966e-14 2.4052919e-13 ... 1.8486422e-13
#   1.2937895e-12 7.1462211e-14]
#  [2.3631704e-23 1.4255839e-27 5.5586620e-25 ... 1.0181905e-25
#   1.6021953e-22 1.4855783e-25]]
# (10000, 784)
